# %% [markdown]
# # **Proyecto: CALCULADORA** 🔢🧮
#
# ***Instrucciones:*** 📘👇
#
# 1.   Selecciona una opción correspondiente a la operación que desea realizar. ➕➖✖️➗
# 2.   Elije tu primer dígito. 🔢
# 3.   Elige tu segundo dígito. 🔢
# 4.   Espera el resultado deseado. ⏳✨

# %%
print("┌───────────────────────────────────┐")
print("│⭐ Bienvenido a la Calculadora  ⭐│")
print("└───────────────────────────────────┘")
# Out:
# ┌───────────────────────────────────┐
# │⭐ Bienvenido a la Calculadora  ⭐│
# └───────────────────────────────────┘

# %%
var1 = ""
while var1!="5":
    var1=input("Elige lo que quieras hacer\n 1-Suma\n 2-Resta\n 3-Multiplicacion\n 4-Division\n 5-Salida\n")
    if var1=="5":
        print("Hasta luego")
    elif var1=="1":
        var2=int(input("Elige el primer numero\n"))
        var3=int(input("Elige el segundo numero\n"))
        print("El resultado de la suma es",var2+var3)
    elif var1=="2":
        var2=int(input("Elige el primer numero\n"))
        var3=int(input("Elige el segundo numero\n"))
        print("El resultado de la resta es",var2-var3)
    elif var1=="3":
        var2=int(input("Elige el primer numero\n"))
        var3=int(input("Elige el segundo numero\n"))
        print("El resultado de la multiplicacion es",var2*var3)
    elif var1=="4":
        var2=int(input("Elige el primer numero\n"))
        var3=int(input("Elige el segundo numero\n"))
        print("El resultado de la division es",var2/var3)
    else:
        print("Adios.")

# %% [markdown]
# ## **Integrantes:**
#
# 1.  Skarleth Regina Ortega Perez
# 2.  Valeria Fernanda Tapia Barbabosa
# 3. Sarahi Perez Carrasco
#
# 1.  Angel Bautista Hernandez
# 2.  Fatima Garcia Monroy
